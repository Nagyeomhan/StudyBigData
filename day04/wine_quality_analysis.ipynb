# %% [markdown]
# ## 와인 품질 분석/예측
#
# ### 기본 통계 방법
#
# #### 와인데이터 수집
#
# https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/

# %% [markdown]
# #### 와인데이터 로드
#
# ##### 기본 패키지 import

# %%
import pandas as pd

# %% [markdown]
# ##### 준비된 와인데이터 로드하기

# %%
red_df = pd.read_csv('./data/winequality-red.csv', sep=';')
white_df = pd.read_csv('./data/winequality-white.csv', sep=';')

# %% [markdown]
# ##### 읽은 데이터 확인

# %%
red_df.head(n=10)  # n= 빼고 10만 적어도 됨
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# 5      9.4        5
# 6      9.4        5
# 7     10.0        7
# 8      9.5        7
# 9     10.5        5

# %%
white_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
# 데이터프레임의 형태 조회
red_df.shape
# Out:
# (1599, 12)

# %%
white_df.shape
# Out:
# (4898, 12)

# %% [markdown]
# ##### 와인별로 구분자 type(red, white) 추가

# %%
red_df.insert(0, column='type', value='red')
red_df.head()
# Out:
#   type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  red            7.4              0.70         0.00             1.9
# 1  red            7.8              0.88         0.00             2.6
# 2  red            7.8              0.76         0.04             2.3
# 3  red           11.2              0.28         0.56             1.9
# 4  red            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5
# 3       0.58      9.8        6
# 4       0.56      9.4        5

# %%
red_df.shape
# Out:
# (1599, 13)

# %%
white_df.insert(0, column='type', value='white')
white_df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
white_df.shape
# Out:
# (4898, 13)

# %% [markdown]
# ##### 레드와인, 화이트와인 데이터를 결합 → wine_df

# %%
wine_df = pd.concat([red_df, white_df])

# %%
wine_df.shape
# Out:
# (6497, 13)

# %%
wine_df.head()
# Out:
#   type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  red            7.4              0.70         0.00             1.9
# 1  red            7.8              0.88         0.00             2.6
# 2  red            7.8              0.76         0.04             2.3
# 3  red           11.2              0.28         0.56             1.9
# 4  red            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5
# 3       0.58      9.8        6
# 4       0.56      9.4        5

# %%
wine_df.tail()  # 앞에 index 번호가 잘못 들어가 있다
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 4893  white            6.2              0.21         0.29             1.6
# 4894  white            6.6              0.32         0.36             8.0
# 4895  white            6.5              0.24         0.19             1.2
# 4896  white            5.5              0.29         0.30             1.1
# 4897  white            6.0              0.21         0.38             0.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 4893      0.039                 24.0                  92.0  0.99114  3.27
# 4894      0.047                 57.0                 168.0  0.99490  3.15
# 4895      0.041                 30.0                 111.0  0.99254  2.99
# 4896      0.022                 20.0                 110.0  0.98869  3.34
# 4897      0.020                 22.0                  98.0  0.98941  3.26
#
#       sulphates  alcohol  quality
# 4893       0.50     11.2        6
# 4894       0.46      9.6        5
# 4895       0.46      9.4        6
# 4896       0.38     12.8        7
# 4897       0.32     11.8        6

# %%
wine_df.reset_index(drop=True, inplace=False)  # 이렇게 해결할 수도 있다
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0       red            7.4              0.70         0.00             1.9
# 1       red            7.8              0.88         0.00             2.6
# 2       red            7.8              0.76         0.04             2.3
# 3       red           11.2              0.28         0.56             1.9
# 4       red            7.4              0.70         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 6492  white            6.2              0.21         0.29             1.6
# 6493  white            6.6              0.32         0.36             8.0
# 6494  white            6.5              0.24         0.19             1.2
# 6495  white            5.5              0.29         0.30             1.1
# 6496  white            6.0              0.21         0.38             0.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.076                 11.0                  34.0  0.99780  3.51
# 1         0.098                 25.0                  67.0  0.99680  3.20
# 2         0.092                 15.0                  54.0  0.99700  3.26
# 3         0.075                 17.0                  60.0  0.99800  3.16
# 4         0.076                 11.0                  34.0  0.99780  3.51
# ...         ...                  ...                   ...      ...   ...
# 6492      0.039                 24.0                  92.0  0.99114  3.27
# 6493      0.047                 57.0                 168.0  0.99490  3.15
# 6494      0.041                 30.0                 111.0  0.99254  2.99
# 6495      0.022                 20.0                 110.0  0.98869  3.34
# 6496      0.020                 22.0                  98.0  0.98941  3.26
#
#       sulphates  alcohol  quality
# 0          0.56      9.4        5
# 1          0.68      9.8        5
# 2          0.65      9.8        5
# 3          0.58      9.8        6
# 4          0.56      9.4        5
# ...         ...      ...      ...
# 6492       0.50     11.2        6
# 6493       0.46      9.6        5
# 6494       0.46      9.4        6
# 6495       0.38     12.8        7
# 6496       0.32     11.8        6
#
# [6497 rows x 13 columns]

# %% [markdown]
# ##### wine_df를 csv로 저장

# %%
wine_df.to_csv('./data/wine.csv', index=False, encoding='utf-8')

# %%
wine = pd.read_csv('./data/wine.csv', encoding='utf-8')

# %%
wine.tail()  # 다시 읽어들이니까 앞의 문제가 사라졌다
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6492  white            6.2              0.21         0.29             1.6
# 6493  white            6.6              0.32         0.36             8.0
# 6494  white            6.5              0.24         0.19             1.2
# 6495  white            5.5              0.29         0.30             1.1
# 6496  white            6.0              0.21         0.38             0.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6492      0.039                 24.0                  92.0  0.99114  3.27
# 6493      0.047                 57.0                 168.0  0.99490  3.15
# 6494      0.041                 30.0                 111.0  0.99254  2.99
# 6495      0.022                 20.0                 110.0  0.98869  3.34
# 6496      0.020                 22.0                  98.0  0.98941  3.26
#
#       sulphates  alcohol  quality
# 6492       0.50     11.2        6
# 6493       0.46      9.6        5
# 6494       0.46      9.4        6
# 6495       0.38     12.8        7
# 6496       0.32     11.8        6

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
wine.tail(n=10)
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6487  white            6.8             0.220         0.36            1.20
# 6488  white            4.9             0.235         0.27           11.75
# 6489  white            6.1             0.340         0.29            2.20
# 6490  white            5.7             0.210         0.32            0.90
# 6491  white            6.5             0.230         0.38            1.30
# 6492  white            6.2             0.210         0.29            1.60
# 6493  white            6.6             0.320         0.36            8.00
# 6494  white            6.5             0.240         0.19            1.20
# 6495  white            5.5             0.290         0.30            1.10
# 6496  white            6.0             0.210         0.38            0.80
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6487      0.052                 38.0                 127.0  0.99330  3.04
# 6488      0.030                 34.0                 118.0  0.99540  3.07
# 6489      0.036                 25.0                 100.0  0.98938  3.06
# 6490      0.038                 38.0                 121.0  0.99074  3.24
# 6491      0.032                 29.0                 112.0  0.99298  3.29
# 6492      0.039                 24.0                  92.0  0.99114  3.27
# 6493      0.047                 57.0                 168.0  0.99490  3.15
# 6494      0.041                 30.0                 111.0  0.99254  2.99
# 6495      0.022                 20.0                 110.0  0.98869  3.34
# 6496      0.020                 22.0                  98.0  0.98941  3.26
#
#       sulphates  alcohol  quality
# 6487       0.54      9.2        5
# 6488       0.50      9.4        6
# 6489       0.44     11.8        6
# 6490       0.46     10.6        6
# 6491       0.54      9.7        5
# 6492       0.50     11.2        6
# 6493       0.46      9.6        5
# 6494       0.46      9.4        6
# 6495       0.38     12.8        7
# 6496       0.32     11.8        6

# %%
wine.columns = wine.columns.str.replace(' ','_')  # 컬럼 이름에 공백 있으면 안 됨
wine.head()
# Out:
#   type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0  red            7.4              0.70         0.00             1.9
# 1  red            7.8              0.88         0.00             2.6
# 2  red            7.8              0.76         0.04             2.3
# 3  red           11.2              0.28         0.56             1.9
# 4  red            7.4              0.70         0.00             1.9
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5
# 3       0.58      9.8        6
# 4       0.56      9.4        5

# %%
wine.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378
# std       0.160787     0.148806     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
wine.quality
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 6492    6
# 6493    5
# 6494    6
# 6495    7
# 6496    6
# Name: quality, Length: 6497, dtype: int64

# %%
# 전체 와인 quality 등급 리스트
sorted(wine.quality.unique())
# Out:
# [3, 4, 5, 6, 7, 8, 9]

# %%
wine.quality.value_counts()
# Out:
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: quality, dtype: int64

# %% [markdown]
# ##### 와인 그룹별로 확인

# %%
wine.groupby('type')['quality'].describe()
# Out:
#         count      mean       std  min  25%  50%  75%  max
# type
# red    1599.0  5.636023  0.807569  3.0  5.0  6.0  6.0  8.0
# white  4898.0  5.877909  0.885639  3.0  5.0  6.0  6.0  9.0

# %%
wine.groupby('type')['alcohol'].describe()
# Out:
#         count       mean       std  min  25%   50%   75%   max
# type
# red    1599.0  10.422983  1.065668  8.4  9.5  10.2  11.1  14.9
# white  4898.0  10.514267  1.230621  8.0  9.5  10.4  11.4  14.2

# %%
wine.groupby('type')['alcohol'].agg(['mean','std'])
# Out:
#             mean       std
# type
# red    10.422983  1.065668
# white  10.514267  1.230621

# %% [markdown]
# ### t-검정 / 회귀분석
#
# #### 라이브러리 import

# %%
from scipy import stats

# %%
# statsmodels 패키지 추가 - cmd에서 설치하는 것을 권장
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.13.2-cp310-cp310-win_amd64.whl (9.1 MB)
#      ---------------------------------------- 9.1/9.1 MB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from statsmodels) (1.23.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from statsmodels) (21.3)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
#      ------------------------------------- 233.7/233.7 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.25 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from statsmodels) (1.4.3)
# Requirement already satisfied: scipy>=1.3 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from statsmodels) (1.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.25->statsmodels) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.2 statsmodels-0.13.2

# %% [markdown]
# ##### 회귀분석을 위한 statsmodels 패키지 import

# %%
from statsmodels.formula.api import ols, glm

# %%
red_wine_quality = wine.loc[wine['type'] == 'red', 'quality']
red_wine_quality
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
# 이렇게 할 수도 있다
red_wine_quality = wine.loc[wine.type == 'red', 'quality']
red_wine_quality
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
white_wine_quality = wine.loc[wine['type'] == 'white', 'quality']
white_wine_quality
# Out:
# 1599    6
# 1600    6
# 1601    6
# 1602    6
# 1603    6
#        ..
# 6492    6
# 6493    5
# 6494    6
# 6495    7
# 6496    6
# Name: quality, Length: 4898, dtype: int64

# %%
# T-검정 (두 그룹 사이의 차이)
stats.ttest_ind(red_wine_quality, white_wine_quality, equal_var=False)
# Out:
# Ttest_indResult(statistic=-10.149363059143164, pvalue=8.168348870049682e-24)

# %%
# 선형회귀분석
Rformula = 'quality ~ fixed_acidity + volatile_acidity + citric_acid + residual_sugar + chlorides + free_sulfur_dioxide + total_sulfur_dioxide + density + pH + sulphates + alcohol'

# %%
regre_result = ols(Rformula, data=wine).fit()
regre_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.292
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     243.3
# Date:                Fri, 05 Aug 2022   Prob (F-statistic):               0.00
# Time:                        13:52:15   Log-Likelihood:                -7215.5
# No. Observations:                6497   AIC:                         1.445e+04
# Df Residuals:                    6485   BIC:                         1.454e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               55.7627     11.894      4.688      0.000      32.447      79.079
# fixed_acidity            0.0677      0.016      4.346      0.000       0.037       0.098
# volatile_acidity        -1.3279      0.077    -17.162      0.000      -1.480      -1.176
# citric_acid             -0.1097      0.080     -1.377      0.168      -0.266       0.046
# residual_sugar           0.0436      0.005      8.449      0.000       0.033       0.054
# chlorides               -0.4837      0.333     -1.454      0.146      -1.136       0.168
# free_sulfur_dioxide      0.0060      0.001      7.948      0.000       0.004       0.007
# total_sulfur_dioxide    -0.0025      0.000     -8.969      0.000      -0.003      -0.002
# density                -54.9669     12.137     -4.529      0.000     -78.760     -31.173
# pH                       0.4393      0.090      4.861      0.000       0.262       0.616
# sulphates                0.7683      0.076     10.092      0.000       0.619       0.917
# alcohol                  0.2670      0.017     15.963      0.000       0.234       0.300
# ==============================================================================
# Omnibus:                      144.075   Durbin-Watson:                   1.646
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              324.712
# Skew:                          -0.006   Prob(JB):                     3.09e-71
# Kurtosis:                       4.095   Cond. No.                     2.49e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.49e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### OLS모델로 계산된 회귀분석 결과로 새 샘플 와인에 대한 품질등급 예측

# %%
# quality, type은 제거하고 나머지 컬럼들이 알파벳순으로 정렬됨
sample1 = wine[wine.columns.difference(['quality', 'type'])]
sample1 = sample1[0:5][:]  # 문제 : 이렇게 하면 red wine밖에 안 나옴
sample1
# Out:
#    alcohol  chlorides  citric_acid  density  fixed_acidity  \
# 0      9.4      0.076         0.00   0.9978            7.4
# 1      9.8      0.098         0.00   0.9968            7.8
# 2      9.8      0.092         0.04   0.9970            7.8
# 3      9.8      0.075         0.56   0.9980           11.2
# 4      9.4      0.076         0.00   0.9978            7.4
#
#    free_sulfur_dioxide    pH  residual_sugar  sulphates  total_sulfur_dioxide  \
# 0                 11.0  3.51             1.9       0.56                  34.0
# 1                 25.0  3.20             2.6       0.68                  67.0
# 2                 15.0  3.26             2.3       0.65                  54.0
# 3                 17.0  3.16             1.9       0.58                  60.0
# 4                 11.0  3.51             1.9       0.56                  34.0
#
#    volatile_acidity
# 0              0.70
# 1              0.88
# 2              0.76
# 3              0.28
# 4              0.70

# %%
sample1_predict = regre_result.predict(sample1)
sample1_predict
# Out:
# 0    4.997607
# 1    4.924993
# 2    5.034663
# 3    5.680333
# 4    4.997607
# dtype: float64

# %%
wine[0:5]['quality']  # 실제 데이터와 일치하는지 비교
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
# 새로운 와인에서 추출된 데이터를 가지고 등급을 예측
data = {'alcohol':[9.0, 0.88], 'chlorides':[0.055,0.04], 'citric_acid':[0.3,0.4], 'density':[0.996,0.91], 'fixed_acidity':[8.5,8.1], 'free_sulfur_dioxide':[30.0,31.0], 'pH':[3.25,3.01], 'residual_sugar':[6.1,5.8], 'sulphates':[0.4,0.35], 'total_sulfur_dioxide':[98.0,99], 'volatile_acidity':[0.8,0.5]}

new_sample = pd.DataFrame(data, columns=sample1.columns)
new_sample
# Out:
#    alcohol  chlorides  citric_acid  density  fixed_acidity  \
# 0     9.00      0.055          0.3    0.996            8.5
# 1     0.88      0.040          0.4    0.910            8.1
#
#    free_sulfur_dioxide    pH  residual_sugar  sulphates  total_sulfur_dioxide  \
# 0                 30.0  3.25             6.1       0.40                  98.0
# 1                 31.0  3.01             5.8       0.35                  99.0
#
#    volatile_acidity
# 0               0.8
# 1               0.5

# %%
new_sample_predict = regre_result.predict(new_sample)

# %%
new_sample_predict
# Out:
# 0    4.809094
# 1    7.582129
# dtype: float64

# %% [markdown]
# #### 예측결과 의사결정
# - 1번 → 75,000원
# - 2번 → 24,000원

# %% [markdown]
# ### 시각화
#
# #### 와인 유형에 따른 품질등급 히스토그램

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('dark')
plt.rcParams['font.family'] = 'NanumSquare'
sns.distplot(red_wine_quality, kde=True, color='red', label='red wine')
sns.distplot(white_wine_quality, kde=True, color='blue', label='white wine')
plt.title('와인 종류에 따른 등급 분석')
plt.legend()

plt.show()
# Out:
# C:\Users\admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### 선형회귀 분석값 시각화

# %%
# 패키지 import
import statsmodels.api as sm

others = list(set(wine.columns).difference(set(['quality', 'fixed_acidity'])))
others
# Out:
# ['citric_acid',
#  'chlorides',
#  'free_sulfur_dioxide',
#  'volatile_acidity',
#  'alcohol',
#  'density',
#  'pH',
#  'residual_sugar',
#  'sulphates',
#  'total_sulfur_dioxide',
#  'type']

# %%
p, resids = sm.graphics.plot_partregress('quality', 'fixed_acidity', others, data=wine, ret_coords=True)
plt.show()
# Out:
# eval_env: 1

# %%
(p, resids)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  (array([-0.0614815 , -0.02284876, -0.14904951, ..., -0.63960939,
#          -0.27128396, -0.13872942]),
#   array([ 0.02363191,  0.08667536, -0.04281161, ...,  0.55410286,
#           0.5178791 , -0.2565605 ])))

# %%
fig = plt.figure(figsize=(8, 13))
sm.graphics.plot_partregress_grid(regre_result, fig=fig)
plt.show()  # 결과를 보면 선형회귀로 하는건 의미가 없어보인다
# Out:
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
